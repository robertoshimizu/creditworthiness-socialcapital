# %%
import numpy as np
import pandas as pd
import os

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /usr/snap/notebooks/microfinance_indian_villages/datav4.0/Stata Replication/data

# %%
os.listdir(path='.')
# Out:
# ['.ipynb_checkpoints', 'cross_sectional.dta', 'panel.dta', 'Untitled.ipynb']

# %%
df1 = pd.io.stata.read_stata('cross_sectional.dta')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   village                          43 non-null     float32
#  1   mf                               43 non-null     float32
#  2   degree_leader                    43 non-null     float32
#  3   eigenvector_centrality_leader    43 non-null     float32
#  4   between_centrality_leader        43 non-null     float32
#  5   bonacich_centrality_leader       43 non-null     float32
#  6   decay_centrality_leader          43 non-null     float32
#  7   diffusion_centrality_leader      43 non-null     float32
#  8   closeness_centrality_leader      43 non-null     float32
#  9   communication_centrality_leader  43 non-null     float32
#  10  numHH                            43 non-null     int16
#  11  fractionLeaders                  43 non-null     float32
# ...

# %%
df1.head()
# Out:
#    village        mf  degree_leader  eigenvector_centrality_leader  \
# 0      1.0  0.214290         21.111                       0.088717
# 1      2.0  0.138730         15.727                       0.078247
# 2      3.0  0.140080         16.636                       0.064052
# 3      4.0  0.067873         16.625                       0.066191
# 4      6.0  0.239130         13.600                       0.121900
#
#    between_centrality_leader  bonacich_centrality_leader  \
# 0                   0.039078                      4.5436
# 1                   0.040030                      4.3158
# 2                   0.019945                      4.3200
# 3                   0.032432                      4.2553
# 4                   0.043495                      4.9279
#
#    decay_centrality_leader  diffusion_centrality_leader  \
# 0                   5.8691                       7.9435
# 1                   4.0554                       8.1701
# ...

# %%
df2 = pd.io.stata.read_stata('panel.dta')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325 entries, 0 to 324
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   village                          325 non-null    float32
#  1   t                                325 non-null    float32
#  2   dynamicMF_empirical              282 non-null    float64
#  3   dynamicMF_simulated              325 non-null    float32
#  4   eigenvector_centrality_leader    325 non-null    float32
#  5   between_centrality_leader        325 non-null    float32
#  6   bonacich_centrality_leader       325 non-null    float32
#  7   decay_centrality_leader          325 non-null    float32
#  8   diffusion_centrality_leader      325 non-null    float32
#  9   closeness_centrality_leader      325 non-null    float32
#  10  communication_centrality_leader  325 non-null    float32
# ...

# %%
df2.head()
# Out:
#    village    t  dynamicMF_empirical  dynamicMF_simulated  \
# 0      1.0  0.0             0.000000             0.000000
# 1      1.0  1.0             0.131868             0.041966
# 2      1.0  2.0             0.153846             0.092046
# 3      1.0  3.0             0.203297             0.147030
# 4      1.0  4.0             0.203297             0.186200
#
#    eigenvector_centrality_leader  between_centrality_leader  \
# 0                       0.088717                   0.039078
# 1                       0.088717                   0.039078
# 2                       0.088717                   0.039078
# 3                       0.088717                   0.039078
# 4                       0.088717                   0.039078
#
#    bonacich_centrality_leader  decay_centrality_leader  \
# 0                      4.5436                   5.8691
# 1                      4.5436                   5.8691
# 2                      4.5436                   5.8691
# ...
